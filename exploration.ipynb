# %% [markdown]
# # Exploration
#
# This is an exploratory notebook where I just attempt to load and explore the data provided in the public repository. I then compute the new columns that I would want as more explanatory statistics for the data.

# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
case_data = pd.read_csv("https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_malaysia.csv")
test_data = pd.read_csv("https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/tests_malaysia.csv")

diff = len(test_data) - len(case_data)

test_data = test_data.drop(test_data.index[:diff])
test_data = test_data.reset_index()

print(test_data)
print(case_data)
# Out:
#      index        date  rtk-ag    pcr
# 0       52  2020-03-16       0   2468
# 1       53  2020-03-17       0   2927
# 2       54  2020-03-18       0   3411
# 3       55  2020-03-19       0   3304
# 4       56  2020-03-20       0   3635
# ..     ...         ...     ...    ...
# 497    549  2021-07-26   91233  57972
# 498    550  2021-07-27   84147  70425
# 499    551  2021-07-28   77798  73500
# 500    552  2021-07-29   79001  80399
# 501    553  2021-07-30   72807  81791
#
# [502 rows x 4 columns]
#            date  cases_new  cluster_import  cluster_religious  \
# 0    2020-03-16        553             NaN                NaN
# 1    2020-03-17        120             NaN                NaN
# 2    2020-03-18        117             NaN                NaN
# 3    2020-03-19        110             NaN                NaN
# 4    2020-03-20        130             NaN                NaN
# ..          ...        ...             ...                ...
# ...

# %%
total_testing = test_data["pcr"] + test_data["rtk-ag"]
total_cases = case_data["cases_new"]
dates = test_data["date"]

case_test_ratio = (total_cases / total_testing).round(5)

frame = {"date": dates, "total_testing": total_testing, "total_cases": total_cases, "case_test_ratio": case_test_ratio}

new_df = pd.DataFrame(frame)
new_df
# Out:
#            date  total_testing  total_cases  case_test_ratio
# 0    2020-03-16           2468          553          0.22407
# 1    2020-03-17           2927          120          0.04100
# 2    2020-03-18           3411          117          0.03430
# 3    2020-03-19           3304          110          0.03329
# 4    2020-03-20           3635          130          0.03576
# ..          ...            ...          ...              ...
# 497  2021-07-26         149205        14516          0.09729
# 498  2021-07-27         154572        16117          0.10427
# 499  2021-07-28         151298        17405          0.11504
# 500  2021-07-29         159400        17170          0.10772
# 501  2021-07-30         154598        16840          0.10893
#
# [502 rows x 4 columns]
